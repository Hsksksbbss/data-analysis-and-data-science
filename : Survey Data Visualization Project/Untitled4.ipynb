# %% [markdown]
# # Load and Check the Dataset

# %%
import pandas as pd

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv("D:/downloads 2/survey_dataset.csv")

# %%
df.head()
# Out:
#   Age Group  Gender  Satisfaction (1-5) Platform Preferred
# 0     18-25    Male                   4            YouTube
# 1     26-35  Female                   5          Instagram
# 2     36-45    Male                   3           Facebook
# 3     18-25  Female                   4            Twitter
# 4     26-35   Other                   2            YouTube

# %% [markdown]
# # Bar Chart – Platform Preference

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Platform Preferred', palette='Set2')
plt.title('Platform Preference')
plt.xlabel('Platform')
plt.ylabel('Number of Respondents')
plt.xticks(rotation=15)
plt.show()
# Out:
# C:\Users\Sandipan Jana\AppData\Local\Temp\ipykernel_25312\3536959509.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Platform Preferred', palette='Set2')

# %% [markdown]
# #  Pie Chart – Gender Distribution

# %%
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=sns.color_palette('Set3'))
plt.title('Gender Distribution')
plt.show()

# %%
heatmap_data = pd.crosstab(df['Age Group'], df['Satisfaction (1-5)'])
plt.figure(figsize=(8, 5))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', fmt='d')
plt.title('Satisfaction by Age Group')
plt.xlabel('Satisfaction Score')
plt.ylabel('Age Group')
plt.show()

# %%
import plotly.express as px
import numpy as np
import pandas as pd

# If df is already defined, you might need to convert string columns
# Convert any columns with unicode data type to string
if 'df' in locals() or 'df' in globals():
    # Convert string columns to the new np.str_ type
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].astype(str)

# Create the plot
fig = px.bar(df, x='Platform Preferred', color='Gender', title='Platform Preference by Gender')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import plotly.express as px
#       2 import numpy as np
#       3 import pandas as pd
#
# File D:\downloads 2\jupyter2\Lib\site-packages\plotly\express\__init__.py:14
#       8 if pd is None:
#       9     raise ImportError(
#      10         """\
#      11 Plotly express requires pandas to be installed."""
#      12     )
# ---> 14 from ._imshow import imshow
#      15 from ._chart_types import (  # noqa: F401
#      16     scatter,
#      17     scatter_3d,
#    (...)     54     density_mapbox,
#      55 )
#      58 from ._core import (  # noqa: F401
#      59     set_mapbox_access_token,
#      60     defaults,
#      61     get_trendline_results,
#      62     NO_COLOR,
#      63 )
#
# File D:\downloads 2\jupyter2\Lib\site-packages\plotly\express\_imshow.py:11
# ...
